# %% [markdown]
# # Entradas y salidas

# %%
import numpy as np
import pandas as pd

# Definimos un dataframe con datos de ejemplos
df = pd.DataFrame(np.random.randn(10, 5), columns=["A", "B", "C", "D", "E"])

df
# Out:
#           A         B         C         D         E
# 0 -0.195038 -0.470186 -0.377693  1.062603 -2.350430
# 1  0.276137  0.526871 -1.050435 -0.051677  0.774512
# 2  0.910388 -0.992693  0.870712 -1.453826  1.358140
# 3 -2.033586 -0.345650 -0.837239  1.698382  0.578064
# 4  0.111505 -1.835556 -0.379847 -0.459630 -1.197687
# 5 -0.551438  0.597910  0.083967  0.384263  1.928481
# 6  0.848155  2.700418  0.961803 -0.835807  2.331483
# 7 -0.463018  0.118278 -1.183152  0.688691 -1.727086
# 8  0.660841  0.114250  0.687112 -0.947717 -1.786401
# 9 -1.438903 -0.568151 -0.304352  0.963250  0.946312

# %% [markdown]
# ## CSV
#
# ### Guardar a CSV

# %%
df.to_csv('datos.csv', index=False)

# %%
# Borramos el df de la memoria
del(df)

# %%
# ya no se encunetra en la memoria
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# c:\Users\ANDRES-PC\Desktop\Github\recursos-python-data-analytics\Pandas\Módulo 02 - Pandas\08 - Entradas y salidas.ipynb Cell 6 line 1
# ----> <a href='vscode-notebook-cell:/c%3A/Users/ANDRES-PC/Desktop/Github/recursos-python-data-analytics/Pandas/M%C3%B3dulo%2002%20-%20Pandas/08%20-%20Entradas%20y%20salidas.ipynb#X54sZmlsZQ%3D%3D?line=0'>1</a> df
#
# NameError: name 'df' is not defined

# %% [markdown]
# ### Cargar desde CSV

# %%
df = pd.read_csv('datos.csv')

df
# Out:
#           A         B         C         D         E
# 0 -1.002746  0.841727 -0.819142  0.034147 -0.898676
# 1 -0.731084  0.102724  0.087916  2.125169  1.816986
# 2  0.290780 -0.491395 -0.556531  1.666097  0.841258
# 3  1.159650  0.511966  0.145541 -1.186410  0.878983
# 4 -0.390913 -0.036926 -0.510251  0.497481  0.076077
# 5  0.739531 -0.857722  0.135570  0.237839 -1.537218
# 6  0.081995 -1.447707 -0.662703 -1.348338 -2.219009
# 7 -0.778938 -1.593397 -0.184512 -0.638577 -0.709451
# 8  0.005694  1.168694 -0.098648 -0.219383  2.527017
# 9 -0.128540 -0.361259  0.160029 -0.589836 -0.417346

# %% [markdown]
# ## JSON
#
# ### Guardar a JSON

# %%
df.to_json('datos.json')

# %%
# Borramos el df de la memoria
del(df)

# %% [markdown]
# ### Cargar desde JSON

# %%
df = pd.read_json('datos.json')

df
# Out:
#           A         B         C         D         E
# 0 -1.002746  0.841727 -0.819142  0.034147 -0.898676
# 1 -0.731084  0.102724  0.087916  2.125169  1.816986
# 2  0.290780 -0.491395 -0.556531  1.666097  0.841258
# 3  1.159650  0.511966  0.145541 -1.186410  0.878983
# 4 -0.390913 -0.036926 -0.510251  0.497481  0.076077
# 5  0.739531 -0.857722  0.135570  0.237839 -1.537218
# 6  0.081995 -1.447707 -0.662703 -1.348338 -2.219009
# 7 -0.778938 -1.593397 -0.184512 -0.638577 -0.709451
# 8  0.005694  1.168694 -0.098648 -0.219383  2.527017
# 9 -0.128540 -0.361259  0.160029 -0.589836 -0.417346

# %% [markdown]
# ## Excel
#
# Necesitamos instalar el módulo `openpyxl` para generar y leer este formato:
#
#     pip install openpyxl

# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\andres-pc\appdata\local\programs\python\python311\lib\site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in c:\users\andres-pc\appdata\local\programs\python\python311\lib\site-packages (from openpyxl) (1.1.0)

# %% [markdown]
# ### Guardar a Excel

# %%
df.to_excel('datos.xlsx', sheet_name='Sheet1', index=False)

# %%
# Borramos el df de la memoria
del(df)

# %% [markdown]
# ### Cargar desde Excel

# %%
df = pd.read_excel('datos.xlsx', sheet_name='Sheet1')

df
# Out:
#           A         B         C         D         E
# 0 -1.002746  0.841727 -0.819142  0.034147 -0.898676
# 1 -0.731084  0.102724  0.087916  2.125169  1.816986
# 2  0.290780 -0.491395 -0.556531  1.666097  0.841258
# 3  1.159650  0.511966  0.145541 -1.186410  0.878983
# 4 -0.390913 -0.036926 -0.510251  0.497481  0.076077
# 5  0.739531 -0.857722  0.135570  0.237839 -1.537218
# 6  0.081995 -1.447707 -0.662703 -1.348338 -2.219009
# 7 -0.778938 -1.593397 -0.184512 -0.638577 -0.709451
# 8  0.005694  1.168694 -0.098648 -0.219383  2.527017
# 9 -0.128540 -0.361259  0.160029 -0.589836 -0.417346

# %% [markdown]
# ## HTML
#
# Podemos extraer información directamente desde tablas de páginas web a partir de la URL.
#
# Esto se consigue haciendo web scrapping con los módulos `lxml` y `BeautifulSoup4`, por lo que necesitamos instalarlos:
#
#     pip install lxml BeautifulSoup4

# %%
# !pip install lxml BeautifulSoup4
# Out:
# Collecting lxml
#   Downloading lxml-4.9.3-cp311-cp311-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: BeautifulSoup4 in c:\users\andres-pc\appdata\local\programs\python\python311\lib\site-packages (4.12.2)
# Requirement already satisfied: soupsieve>1.2 in c:\users\andres-pc\appdata\local\programs\python\python311\lib\site-packages (from BeautifulSoup4) (2.4.1)
# Downloading lxml-4.9.3-cp311-cp311-win_amd64.whl (3.8 MB)
#    ---------------------------------------- 0.0/3.8 MB ? eta -:--:--
#    ------ --------------------------------- 0.6/3.8 MB 19.2 MB/s eta 0:00:01
#    --------------- ------------------------ 1.5/3.8 MB 18.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 2.2/3.8 MB 17.8 MB/s eta 0:00:01
#    ---------------------------------- ----- 3.3/3.8 MB 18.9 MB/s eta 0:00:01
#    ---------------------------------------- 3.8/3.8 MB 17.2 MB/s eta 0:00:00
# Installing collected packages: lxml
# Successfully installed lxml-4.9.3

# %% [markdown]
# Una vez instalado `lxml` y `BeautifulSoup4` reiniciamos el kernel (botón girando al lado de stop) y ya estaremos listos:

# %%
# Realizamos un scrapping de una tabla de la wikipedia
df = pd.read_html('https://web.archive.org/web/20220717170349/https://en.wikipedia.org/wiki/List_of_countries_by_past_fertility_rate')

# %% [markdown]
# Si se encuentra más de una tabla (como en el caso del ejemplo), podemos hacer referencia al primero a través del índice:

# %%
df[2]
# Out:
#     Country/dependent territory  1950–1955  1955–1960  1960–1965  1965–1970  \
# 0                   Afghanistan       7.45       7.45       7.45       7.45
# 1                       Albania       6.23       6.55       6.23       5.26
# 2                       Algeria       7.28       7.38       7.65       7.65
# 3                        Angola       7.30       7.35       7.60       7.60
# 4           Antigua and Barbuda       4.50       4.50       4.30       4.00
# ..                          ...        ...        ...        ...        ...
# 197           Western Sahara[7]       6.34       6.42       6.53       6.60
# 198                       Yemen       7.35       7.40       7.60       7.80
# 199                      Zambia       6.70       6.95       7.25       7.30
# 200                    Zimbabwe       6.80       7.00       7.30       7.40
# 201                       World       4.96       4.89       5.03       4.92
#
#      1970–1975  1975–1980  1980–1985  1985–1990  1990–1995  1995–2000  \
# 0         7.45       7.45       7.45       7.45       7.48       7.65
# 1         4.60       3.90       3.41       3.15       2.79       2.38
# 2         7.57       7.18       6.32       5.30       4.12       2.88
# 3         7.60       7.60       7.40       7.35       7.10       6.75
# 4         3.26       2.24       2.14       2.07       2.09       2.31
# ..         ...        ...        ...        ...        ...        ...
# 197       6.57       6.23       5.33       4.60       4.00       3.40
# 198       7.90       8.60       8.80       8.80       8.20       6.80
# 199       7.40       7.25       6.90       6.60       6.30       6.10
# 200       7.40       7.30       6.74       5.66       4.77       4.20
# 201       4.46       3.87       3.60       3.44       3.02       2.75
#
#      2000–2005  2005–2010  2010–2015
# 0         7.18       6.37       5.26
# 1         1.95       1.64       1.71
# 2         2.38       2.72       2.96
# 3         6.55       6.35       5.95
# 4         2.27       2.17       2.10
# ..         ...        ...        ...
# 197       2.85       2.55       2.60
# 198       5.90       5.00       4.40
# 199       5.95       5.60       5.20
# 200       4.00       4.00       4.00
# 201       2.63       2.57       2.52
#
# [202 rows x 14 columns]

# %% [markdown]
# Podemos hacer un poco de limpieza y dejar los datos presentables:

# %%
# Guardamos el dataframe
fertility_rate = df[2]

fertility_rate.head()
# Out:
#   Country/dependent territory  1950–1955  1955–1960  1960–1965  1965–1970  \
# 0                 Afghanistan       7.45       7.45       7.45       7.45
# 1                     Albania       6.23       6.55       6.23       5.26
# 2                     Algeria       7.28       7.38       7.65       7.65
# 3                      Angola       7.30       7.35       7.60       7.60
# 4         Antigua and Barbuda       4.50       4.50       4.30       4.00
#
#    1970–1975  1975–1980  1980–1985  1985–1990  1990–1995  1995–2000  \
# 0       7.45       7.45       7.45       7.45       7.48       7.65
# 1       4.60       3.90       3.41       3.15       2.79       2.38
# 2       7.57       7.18       6.32       5.30       4.12       2.88
# 3       7.60       7.60       7.40       7.35       7.10       6.75
# 4       3.26       2.24       2.14       2.07       2.09       2.31
#
#    2000–2005  2005–2010  2010–2015
# 0       7.18       6.37       5.26
# 1       1.95       1.64       1.71
# 2       2.38       2.72       2.96
# 3       6.55       6.35       5.95
# 4       2.27       2.17       2.10

# %%
# Renombramos la primera columna para que sea más fácil consultarla
fertility_rate.rename(columns = {'Country/dependent territory':'Country'}, inplace=True)

fertility_rate
# Out:
#                  Country  1950–1955  1955–1960  1960–1965  1965–1970  \
# 0            Afghanistan       7.45       7.45       7.45       7.45
# 1                Albania       6.23       6.55       6.23       5.26
# 2                Algeria       7.28       7.38       7.65       7.65
# 3                 Angola       7.30       7.35       7.60       7.60
# 4    Antigua and Barbuda       4.50       4.50       4.30       4.00
# ..                   ...        ...        ...        ...        ...
# 197    Western Sahara[7]       6.34       6.42       6.53       6.60
# 198                Yemen       7.35       7.40       7.60       7.80
# 199               Zambia       6.70       6.95       7.25       7.30
# 200             Zimbabwe       6.80       7.00       7.30       7.40
# 201                World       4.96       4.89       5.03       4.92
#
#      1970–1975  1975–1980  1980–1985  1985–1990  1990–1995  1995–2000  \
# 0         7.45       7.45       7.45       7.45       7.48       7.65
# 1         4.60       3.90       3.41       3.15       2.79       2.38
# 2         7.57       7.18       6.32       5.30       4.12       2.88
# 3         7.60       7.60       7.40       7.35       7.10       6.75
# 4         3.26       2.24       2.14       2.07       2.09       2.31
# ..         ...        ...        ...        ...        ...        ...
# 197       6.57       6.23       5.33       4.60       4.00       3.40
# 198       7.90       8.60       8.80       8.80       8.20       6.80
# 199       7.40       7.25       6.90       6.60       6.30       6.10
# 200       7.40       7.30       6.74       5.66       4.77       4.20
# 201       4.46       3.87       3.60       3.44       3.02       2.75
#
#      2000–2005  2005–2010  2010–2015
# 0         7.18       6.37       5.26
# 1         1.95       1.64       1.71
# 2         2.38       2.72       2.96
# 3         6.55       6.35       5.95
# 4         2.27       2.17       2.10
# ..         ...        ...        ...
# 197       2.85       2.55       2.60
# 198       5.90       5.00       4.40
# 199       5.95       5.60       5.20
# 200       4.00       4.00       4.00
# 201       2.63       2.57       2.52
#
# [202 rows x 14 columns]

# %% [markdown]
# Ahora podemos realizar consultas cómodamente:

# %%
# Índice de natalidad por país entre los años 2010-2015
fertility_rate[["Country", "2010–2015"]]
# Out:
#                  Country  2010–2015
# 0            Afghanistan       5.26
# 1                Albania       1.71
# 2                Algeria       2.96
# 3                 Angola       5.95
# 4    Antigua and Barbuda       2.10
# ..                   ...        ...
# 197    Western Sahara[7]       2.60
# 198                Yemen       4.40
# 199               Zambia       5.20
# 200             Zimbabwe       4.00
# 201                World       2.52
#
# [202 rows x 2 columns]

# %%
# Misma consulta aplicando el styler para esconder la primera columna
fertility_rate[["Country", "2010–2015"]].head().style.hide(axis=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_a16bd">
#   <thead>
#     <tr>
#       <th id="T_a16bd_level0_col0" class="col_heading level0 col0" >Country</th>
#       <th id="T_a16bd_level0_col1" class="col_heading level0 col1" >2010–2015</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_a16bd_row0_col0" class="data row0 col0" >Afghanistan</td>
#       <td id="T_a16bd_row0_col1" class="data row0 col1" >5.260000</td>
#     </tr>
#     <tr>
#       <td id="T_a16bd_row1_col0" class="data row1 col0" >Albania</td>
#       <td id="T_a16bd_row1_col1" class="data row1 col1" >1.710000</td>
#     </tr>
#     <tr>
#       <td id="T_a16bd_row2_col0" class="data row2 col0" >Algeria</td>
#       <td id="T_a16bd_row2_col1" class="data row2 col1" >2.960000</td>
#     </tr>
#     <tr>
#       <td id="T_a16bd_row3_col0" class="data row3 col0" >Angola</td>
#       <td id="T_a16bd_row3_col1" class="data row3 col1" >5.950000</td>
#     </tr>
#     <tr>
#       <td id="T_a16bd_row4_col0" class="data row4 col0" >Antigua and Barbuda</td>
#       <td id="T_a16bd_row4_col1" class="data row4 col1" >2.100000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Índice de natalidad por país entre los años 1985–1990 ordenado de más a menos (primeros resultados)
fertility_rate[["Country", "1985–1990"]].sort_values(by="1985–1990", ascending=False).head().style.hide(axis=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_24b69">
#   <thead>
#     <tr>
#       <th id="T_24b69_level0_col0" class="col_heading level0 col0" >Country</th>
#       <th id="T_24b69_level0_col1" class="col_heading level0 col1" >1985–1990</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_24b69_row0_col0" class="data row0 col0" >Yemen</td>
#       <td id="T_24b69_row0_col1" class="data row0 col1" >8.800000</td>
#     </tr>
#     <tr>
#       <td id="T_24b69_row1_col0" class="data row1 col0" >Oman</td>
#       <td id="T_24b69_row1_col1" class="data row1 col1" >7.850000</td>
#     </tr>
#     <tr>
#       <td id="T_24b69_row2_col0" class="data row2 col0" >Rwanda</td>
#       <td id="T_24b69_row2_col1" class="data row2 col1" >7.800000</td>
#     </tr>
#     <tr>
#       <td id="T_24b69_row3_col0" class="data row3 col0" >Niger</td>
#       <td id="T_24b69_row3_col1" class="data row3 col1" >7.800000</td>
#     </tr>
#     <tr>
#       <td id="T_24b69_row4_col0" class="data row4 col0" >Burundi</td>
#       <td id="T_24b69_row4_col1" class="data row4 col1" >7.550000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Índice de natalidad por país entre los años 1985–1990 ordenado de más o menos (últimos resultados)
fertility_rate[["Country", "1985–1990"]].sort_values(by="1985–1990", ascending=False).tail().style.hide(axis=0)
# Out:
# <style type="text/css">
# </style>
# <table id="T_42e7a">
#   <thead>
#     <tr>
#       <th id="T_42e7a_level0_col0" class="col_heading level0 col0" >Country</th>
#       <th id="T_42e7a_level0_col1" class="col_heading level0 col1" >1985–1990</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_42e7a_row0_col0" class="data row0 col0" >Austria</td>
#       <td id="T_42e7a_row0_col1" class="data row0 col1" >1.450000</td>
#     </tr>
#     <tr>
#       <td id="T_42e7a_row1_col0" class="data row1 col0" >Guernsey and Jersey (UK)</td>
#       <td id="T_42e7a_row1_col1" class="data row1 col1" >1.450000</td>
#     </tr>
#     <tr>
#       <td id="T_42e7a_row2_col0" class="data row2 col0" >Germany</td>
#       <td id="T_42e7a_row2_col1" class="data row2 col1" >1.430000</td>
#     </tr>
#     <tr>
#       <td id="T_42e7a_row3_col0" class="data row3 col0" >Hong Kong (China)</td>
#       <td id="T_42e7a_row3_col1" class="data row3 col1" >1.360000</td>
#     </tr>
#     <tr>
#       <td id="T_42e7a_row4_col0" class="data row4 col0" >Italy</td>
#       <td id="T_42e7a_row4_col1" class="data row4 col1" >1.350000</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Vamos a transformar todas las columnas desde la segunda hasta la última a valores númericos
fertility_rate = fertility_rate[1:][:].apply(pd.to_numeric, errors='coerce')

# %%
# Ahora podemos consultar la media del índice de natalidad para cada año
fertility_rate.mean()[1:]
# Out:
# 1950–1955    5.447612
# 1955–1960    5.505622
# 1960–1965    5.501791
# 1965–1970    5.281940
# 1970–1975    4.991542
# 1975–1980    4.651343
# 1980–1985    4.393383
# 1985–1990    4.101592
# 1990–1995    3.738209
# 1995–2000    3.388955
# 2000–2005    3.120498
# 2005–2010    2.973234
# 2010–2015    2.837910
# dtype: float64

# %% [markdown]
# Con `Matplotlib`, que aprenderemos en la próxima sección, podemos graficar estos resultados fácilmente:

# %%
import matplotlib.pyplot as plt
plt.rcParams["figure.figsize"] = 10,5

fertility_rate.mean()[1:].plot(kind='line', xlabel="Períodos", ylabel="Media de natalidad mundial")
# Out:
# <Axes: xlabel='Períodos', ylabel='Media de natalidad mundial'>

# %% [markdown]
# La práctica hace el maestro, os animo a hacer vuestras propias pruebas y googlear cualquier cosa que se os ocurra para aprender mucho más.
